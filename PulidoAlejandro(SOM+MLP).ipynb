# %%
import numpy as np
import pandas as pd
from scipy.stats import mode
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import normalize
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

# %% [markdown]
# # DATOS Y CARGA

# %%
# Cargar los datos directamente desde fetch_openml
mnist = fetch_openml('Fashion-MNIST', version=1, as_frame=False)

# Obtener los datos y las etiquetas
X = np.array(mnist.data)
y = np.array(mnist.target)
X.shape,y.shape
# Out:
# ((70000, 784), (70000,))

# %% [markdown]
# # NORMALIZACIÓN EXTENDIDA

# %%
X_norm=normalize(np.append(X,np.ones((X.shape[0],1),dtype=float).reshape(-1,1),axis=1))
X_norm.shape,type(X_norm)
# Out:
# ((70000, 785), numpy.ndarray)

# %% [markdown]
# ### REESCALADO DE LOS DATOS. 600 PARA APRENDIZAJE Y 100 PARA TEST

# %%
XR=X_norm[:700]
YR=y[:700]
XR.shape,YR.shape
# Out:
# ((700, 785), (700,))

# %% [markdown]
# # CLASES A UTILIZAR PARA SOM

# %% [markdown]
# ### Clase Neurona

# %%
class neurona(object):
    def __init__(self, f=0, c=0, dim=0):
        self.c = c
        self.f = f
        self.dim = dim
        self.w = normalize(0.5 - np.random.rand(self.dim).reshape(1,-1))
        self.output = -10.0
        self.label = -1
            
    def predict(self, input):
        self.output = input @ self.w.T
        return self.output
    
    def fit(self, input, alfa=1):
        self.w = normalize(self.w + (alfa*input))
            
    def labeling(self, inputs, targets):
        Y = inputs @ self.w.T
        self.label = targets[np.argmax(Y)]

# %% [markdown]
# ### Clase SOM

# %%
class som():
    
    def __init__(self, filas=1, columnas=1, dim=1, init_radious=0, init_alfa=1):
        self.neronas = []
        self.filas = filas
        self.columnas = columnas
        self.dim = dim
        # self.labels = []
        self.radious = init_radious
        self.init_alfa = init_alfa
        self.t = 0
        # Considera que un mapa rectangular es una lista de objetos "neurona", que viene localizado por sus atributos "fila" y "columna"
        for fila in range(self.filas):
            for columna in range(self.columnas):
                self.neronas.append(neurona(f=fila, c=columna, dim=self.dim))
                
    def fit(self, inputs, max_epochs=1):
        # método similar a otros algoritmo de ML. Recibe las entradas, el radio inicial, el factor de apendizaje inicial,
        # el máximo de épocas y devuelve los pesos ajustados
        P = inputs.shape[0]
        for epoch in range(max_epochs):
            for x in inputs:
                self.alfa = self.init_alfa/(1.0 + float(self.t/P))
                i_gana, y_gana = -1, float('-inf')
                for i in range(self.filas*self.columnas):
                    y_predict = self.neronas[i].predict(x.reshape(1,-1))
                    if y_predict > y_gana:
                        y_gana = y_predict
                        i_gana = i
                f_gana = int(i_gana / self.columnas)
                c_gana = i_gana % self.columnas
                
                # Conjunto de vecinas para un radious
                for f in range(f_gana - self.radious, f_gana + self.radious+1):
                    if f < 0:
                        row = self.filas + f
                    else:
                        if f > self.filas-1:
                            row = f % self.filas
                        else:
                            row = f

                    for c in range(c_gana - self.radious, c_gana + self.radious+1):
                        if c < 0:
                            column = self.columnas + c 
                        else:
                            if c > self.columnas-1:
                                column = c % self.columnas
                            else:
                                column = c
                        self.neronas[(row*self.columnas) + column].fit(x.reshape(1,-1), alfa=self.alfa)
                self.t += 1
                if (self.t % 1000) == 0:
                    print("t =", self.t, "  R =", self.radious, "  epoch =", epoch, "\t\t", end='')
            if self.radious > 0:
                self.radious -= 1
                            
    def neuron_labeling(self, inputs, targets):
        # recorre la neronas de neuronas y va llamanado a su metodo de etiquetado para cada neurona
        for i in range(self.filas*self.columnas):
            self.neronas[i].labeling(inputs, targets)

    def predict(self, inputs):
        # recorre la lista de neuronas y calcula la salida de un conjunto de muestras
        # util para usar la salida del som como entrada a otrso sistemas
        output_list = []
        for x in inputs:
            for i in range(self.filas*self.columnas):
                output_list.append(self.neronas[i].predict(x.reshape(1,-1)))
        return np.array(output_list).reshape(inputs.shape[0], -1)    
    
    def label_predict(self, inputs):
        # clasificación de muestras con el etiquetado de cada neurona hecho previamente
        label_list = []
        i_gana = -1
        for x in inputs:
            i_gana = np.argmax(np.array([self.neronas[i].predict(x) for i in range(self.filas*self.columnas)]))
            label_list.append(self.neronas[i_gana].label)
        return np.array(label_list).reshape(inputs.shape[0], )

# %% [markdown]
# # Inicialización del SOM.

# %%
X_train,X_test,y_train,y_test=train_test_split(XR,YR,test_size=100,stratify=YR)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((600, 785), (100, 785), (600,), (100,))

# %%
mapa_autorganizado=som(filas=15,columnas=9,dim=X_train.shape[1],init_radious=4,init_alfa=10)

# %%
mapa_autorganizado.fit(inputs=X_train,max_epochs=20)
# Out:
# t = 1000   R = 3   epoch = 1 		t = 2000   R = 1   epoch = 3 		t = 3000   R = 0   epoch = 4 		t = 4000   R = 0   epoch = 6 		t = 5000   R = 0   epoch = 8 		t = 6000   R = 0   epoch = 9 		t = 7000   R = 0   epoch = 11 		t = 8000   R = 0   epoch = 13 		t = 9000   R = 0   epoch = 14 		t = 10000   R = 0   epoch = 16 		t = 11000   R = 0   epoch = 18 		t = 12000   R = 0   epoch = 19

# %%
mapa_autorganizado.neuron_labeling(X_train,y_train)

# %%
etiquetas_neuronas_predict=mapa_autorganizado.label_predict(X_test)

# %%
accuracy_score(y_test,etiquetas_neuronas_predict)
# Out:
# 0.72

# %% [markdown]
# # MLP (135X60X10)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_train_mlp=mapa_autorganizado.predict(X_train)

# %%
X_train_mlp.shape
# Out:
# (600, 135)

# %%
X_test_mlp=mapa_autorganizado.predict(X_test)

# %%
X_test_mlp.shape
# Out:
# (100, 135)

# %% [markdown]
# ### ESCALADO

# %%
escalado=MinMaxScaler()

# %%
escalado.fit(np.vstack((X_train_mlp,X_test_mlp)))
# Out:
# MinMaxScaler()

# %%
X_train_mlp=escalado.transform(X_train_mlp)

# %%
X_test_mlp=escalado.transform(X_test_mlp)

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp=MLPClassifier(hidden_layer_sizes=(60,),verbose=True,max_iter=3000)

# %%
mlp.fit(X_train_mlp,y_train)
# Out:
# Iteration 1, loss = 2.35019160
# Iteration 2, loss = 2.24487865
# Iteration 3, loss = 2.18358167
# Iteration 4, loss = 2.13913795
# Iteration 5, loss = 2.09585030
# Iteration 6, loss = 2.05711872
# Iteration 7, loss = 2.01747285
# Iteration 8, loss = 1.97713412
# Iteration 9, loss = 1.93957204
# Iteration 10, loss = 1.90368999
# Iteration 11, loss = 1.86810911
# Iteration 12, loss = 1.83496612
# Iteration 13, loss = 1.80060374
# Iteration 14, loss = 1.76722113
# Iteration 15, loss = 1.73588438
# Iteration 16, loss = 1.70504574
# Iteration 17, loss = 1.67438028
# Iteration 18, loss = 1.64571149
# Iteration 19, loss = 1.61653959
# Iteration 20, loss = 1.58991836
# Iteration 21, loss = 1.56141282
# Iteration 22, loss = 1.53636315
# Iteration 23, loss = 1.51079658
# Iteration 24, loss = 1.48711515
# Iteration 25, loss = 1.46510660
# Iteration 26, loss = 1.44264801
# Iteration 27, loss = 1.42258282
# Iteration 28, loss = 1.40157670
# Iteration 29, loss = 1.38270949
# Iteration 30, loss = 1.36521269
# Iteration 31, loss = 1.34677885
# Iteration 32, loss = 1.33056078
# Iteration 33, loss = 1.31516404
# Iteration 34, loss = 1.30042689
# Iteration 35, loss = 1.28509702
# Iteration 36, loss = 1.27174084
# Iteration 37, loss = 1.25905304
# Iteration 38, loss = 1.24665069
# Iteration 39, loss = 1.23421570
# Iteration 40, loss = 1.22208433
# Iteration 41, loss = 1.21270947
# Iteration 42, loss = 1.20111016
# Iteration 43, loss = 1.18998295
# Iteration 44, loss = 1.17991181
# Iteration 45, loss = 1.16948425
# Iteration 46, loss = 1.16007812
# Iteration 47, loss = 1.15118154
# Iteration 48, loss = 1.14465606
# Iteration 49, loss = 1.13454120
# Iteration 50, loss = 1.12503839
# Iteration 51, loss = 1.11790623
# Iteration 52, loss = 1.10932143
# Iteration 53, loss = 1.10231596
# Iteration 54, loss = 1.09732169
# Iteration 55, loss = 1.08865423
# Iteration 56, loss = 1.08204921
# Iteration 57, loss = 1.07377456
# Iteration 58, loss = 1.06852467
# Iteration 59, loss = 1.06234988
# Iteration 60, loss = 1.05547323
# Iteration 61, loss = 1.04984830
# Iteration 62, loss = 1.04465203
# Iteration 63, loss = 1.03783672
# Iteration 64, loss = 1.03155241
# Iteration 65, loss = 1.02816125
# Iteration 66, loss = 1.02157949
# Iteration 67, loss = 1.01636398
# Iteration 68, loss = 1.01116283
# Iteration 69, loss = 1.00600990
# Iteration 70, loss = 1.00143824
# Iteration 71, loss = 0.99690016
# Iteration 72, loss = 0.99175367
# Iteration 73, loss = 0.98692069
# Iteration 74, loss = 0.98246676
# Iteration 75, loss = 0.97827841
# Iteration 76, loss = 0.97403762
# Iteration 77, loss = 0.96874394
# Iteration 78, loss = 0.96559961
# Iteration 79, loss = 0.96076218
# Iteration 80, loss = 0.96037001
# Iteration 81, loss = 0.95462957
# Iteration 82, loss = 0.94836554
# Iteration 83, loss = 0.94510416
# Iteration 84, loss = 0.94145229
# Iteration 85, loss = 0.93717916
# Iteration 86, loss = 0.93396932
# Iteration 87, loss = 0.93071425
# Iteration 88, loss = 0.92703425
# Iteration 89, loss = 0.92448874
# Iteration 90, loss = 0.92011180
# Iteration 91, loss = 0.91632594
# Iteration 92, loss = 0.91331130
# Iteration 93, loss = 0.90937173
# Iteration 94, loss = 0.90736200
# Iteration 95, loss = 0.90788942
# Iteration 96, loss = 0.90145048
# Iteration 97, loss = 0.89992031
# Iteration 98, loss = 0.89683168
# Iteration 99, loss = 0.89078077
# Iteration 100, loss = 0.89032894
# Iteration 101, loss = 0.88723435
# Iteration 102, loss = 0.88311271
# Iteration 103, loss = 0.88047539
# Iteration 104, loss = 0.87765110
# Iteration 105, loss = 0.87417716
# Iteration 106, loss = 0.87174973
# Iteration 107, loss = 0.86833962
# Iteration 108, loss = 0.86650199
# Iteration 109, loss = 0.86597238
# Iteration 110, loss = 0.86141499
# Iteration 111, loss = 0.86248722
# Iteration 112, loss = 0.85670923
# Iteration 113, loss = 0.85447566
# Iteration 114, loss = 0.85270756
# Iteration 115, loss = 0.84957858
# Iteration 116, loss = 0.84793059
# Iteration 117, loss = 0.84418705
# Iteration 118, loss = 0.84147532
# Iteration 119, loss = 0.84134211
# Iteration 120, loss = 0.83921718
# Iteration 121, loss = 0.83492475
# Iteration 122, loss = 0.83407973
# Iteration 123, loss = 0.83152065
# Iteration 124, loss = 0.83009762
# Iteration 125, loss = 0.82943450
# Iteration 126, loss = 0.82527304
# Iteration 127, loss = 0.82219520
# Iteration 128, loss = 0.82229355
# Iteration 129, loss = 0.81878861
# Iteration 130, loss = 0.81826144
# Iteration 131, loss = 0.81624461
# Iteration 132, loss = 0.81321757
# Iteration 133, loss = 0.81102043
# Iteration 134, loss = 0.81128961
# Iteration 135, loss = 0.80754279
# Iteration 136, loss = 0.80616189
# Iteration 137, loss = 0.80387069
# Iteration 138, loss = 0.80281437
# Iteration 139, loss = 0.79898237
# Iteration 140, loss = 0.79863568
# Iteration 141, loss = 0.79643221
# Iteration 142, loss = 0.79441174
# Iteration 143, loss = 0.79363763
# Iteration 144, loss = 0.79275887
# Iteration 145, loss = 0.79060137
# Iteration 146, loss = 0.78807351
# Iteration 147, loss = 0.78637752
# Iteration 148, loss = 0.78499832
# Iteration 149, loss = 0.78427456
# Iteration 150, loss = 0.78247343
# Iteration 151, loss = 0.78072882
# Iteration 152, loss = 0.77796079
# Iteration 153, loss = 0.77874656
# Iteration 154, loss = 0.77829998
# Iteration 155, loss = 0.77438352
# Iteration 156, loss = 0.77400233
# Iteration 157, loss = 0.77354875
# Iteration 158, loss = 0.77168699
# Iteration 159, loss = 0.76857313
# Iteration 160, loss = 0.76841916
# Iteration 161, loss = 0.76485178
# Iteration 162, loss = 0.76411867
# Iteration 163, loss = 0.76417637
# Iteration 164, loss = 0.76073016
# Iteration 165, loss = 0.75921161
# Iteration 166, loss = 0.75782561
# Iteration 167, loss = 0.75660379
# Iteration 168, loss = 0.75708714
# Iteration 169, loss = 0.75297680
# Iteration 170, loss = 0.75446685
# Iteration 171, loss = 0.75057178
# Iteration 172, loss = 0.75114451
# Iteration 173, loss = 0.74872513
# Iteration 174, loss = 0.74857259
# Iteration 175, loss = 0.74620865
# Iteration 176, loss = 0.74450046
# Iteration 177, loss = 0.74510146
# Iteration 178, loss = 0.74165247
# Iteration 179, loss = 0.74075373
# Iteration 180, loss = 0.74250947
# Iteration 181, loss = 0.73911695
# Iteration 182, loss = 0.73897652
# Iteration 183, loss = 0.73607170
# Iteration 184, loss = 0.73505277
# Iteration 185, loss = 0.73202289
# Iteration 186, loss = 0.73238411
# Iteration 187, loss = 0.73232933
# Iteration 188, loss = 0.72866852
# Iteration 189, loss = 0.73027426
# Iteration 190, loss = 0.72721665
# Iteration 191, loss = 0.72919685
# Iteration 192, loss = 0.72464368
# Iteration 193, loss = 0.72317450
# Iteration 194, loss = 0.72465528
# Iteration 195, loss = 0.72135085
# Iteration 196, loss = 0.72116304
# Iteration 197, loss = 0.72221076
# Iteration 198, loss = 0.71797032
# Iteration 199, loss = 0.71856932
# Iteration 200, loss = 0.71622679
# Iteration 201, loss = 0.71552506
# Iteration 202, loss = 0.71382617
# Iteration 203, loss = 0.71416948
# Iteration 204, loss = 0.71157065
# Iteration 205, loss = 0.71153899
# Iteration 206, loss = 0.71163631
# Iteration 207, loss = 0.70983974
# Iteration 208, loss = 0.70874354
# Iteration 209, loss = 0.70984179
# Iteration 210, loss = 0.70537973
# Iteration 211, loss = 0.70601480
# Iteration 212, loss = 0.70442211
# Iteration 213, loss = 0.70273231
# Iteration 214, loss = 0.70192632
# Iteration 215, loss = 0.70182652
# Iteration 216, loss = 0.69935342
# Iteration 217, loss = 0.69907167
# Iteration 218, loss = 0.69786424
# Iteration 219, loss = 0.69771074
# Iteration 220, loss = 0.69556686
# Iteration 221, loss = 0.69483744
# Iteration 222, loss = 0.69656577
# Iteration 223, loss = 0.69679811
# Iteration 224, loss = 0.69478651
# Iteration 225, loss = 0.69401979
# Iteration 226, loss = 0.69610028
# Iteration 227, loss = 0.69299456
# Iteration 228, loss = 0.68964908
# Iteration 229, loss = 0.68990390
# Iteration 230, loss = 0.68692426
# Iteration 231, loss = 0.68833497
# Iteration 232, loss = 0.68566970
# Iteration 233, loss = 0.68715512
# Iteration 234, loss = 0.68624258
# Iteration 235, loss = 0.68496312
# Iteration 236, loss = 0.68324237
# Iteration 237, loss = 0.68280416
# Iteration 238, loss = 0.68038607
# Iteration 239, loss = 0.67897302
# Iteration 240, loss = 0.67822338
# Iteration 241, loss = 0.67809289
# Iteration 242, loss = 0.67849404
# Iteration 243, loss = 0.67842192
# Iteration 244, loss = 0.67580459
# Iteration 245, loss = 0.67343667
# Iteration 246, loss = 0.67534711
# Iteration 247, loss = 0.67362125
# Iteration 248, loss = 0.67321739
# Iteration 249, loss = 0.67214428
# Iteration 250, loss = 0.67049539
# Iteration 251, loss = 0.67086055
# Iteration 252, loss = 0.66814043
# Iteration 253, loss = 0.67037120
# Iteration 254, loss = 0.66862751
# Iteration 255, loss = 0.66667748
# Iteration 256, loss = 0.66520473
# Iteration 257, loss = 0.66461241
# Iteration 258, loss = 0.66711555
# Iteration 259, loss = 0.66482765
# Iteration 260, loss = 0.66423287
# Iteration 261, loss = 0.66398615
# Iteration 262, loss = 0.66222125
# Iteration 263, loss = 0.66179096
# Iteration 264, loss = 0.66084974
# Iteration 265, loss = 0.65818308
# Iteration 266, loss = 0.65892514
# Iteration 267, loss = 0.65976363
# Iteration 268, loss = 0.65939818
# Iteration 269, loss = 0.65570676
# Iteration 270, loss = 0.65554130
# Iteration 271, loss = 0.65400422
# Iteration 272, loss = 0.65297762
# Iteration 273, loss = 0.65608407
# Iteration 274, loss = 0.65026547
# Iteration 275, loss = 0.65350327
# Iteration 276, loss = 0.65220481
# Iteration 277, loss = 0.65022108
# Iteration 278, loss = 0.64860182
# Iteration 279, loss = 0.65597164
# Iteration 280, loss = 0.64908525
# Iteration 281, loss = 0.65114001
# Iteration 282, loss = 0.64909424
# Iteration 283, loss = 0.64628087
# Iteration 284, loss = 0.64731779
# Iteration 285, loss = 0.64680969
# Iteration 286, loss = 0.64372148
# Iteration 287, loss = 0.64505593
# Iteration 288, loss = 0.64373154
# Iteration 289, loss = 0.64336236
# Iteration 290, loss = 0.64119384
# Iteration 291, loss = 0.64231746
# Iteration 292, loss = 0.64064518
# Iteration 293, loss = 0.63949757
# Iteration 294, loss = 0.63831284
# Iteration 295, loss = 0.64020706
# Iteration 296, loss = 0.63949310
# Iteration 297, loss = 0.63954865
# Iteration 298, loss = 0.63580691
# Iteration 299, loss = 0.63660430
# Iteration 300, loss = 0.63841249
# Iteration 301, loss = 0.63910132
# Iteration 302, loss = 0.63539235
# Iteration 303, loss = 0.63401304
# Iteration 304, loss = 0.63482263
# Iteration 305, loss = 0.63345552
# Iteration 306, loss = 0.63274352
# Iteration 307, loss = 0.63166996
# Iteration 308, loss = 0.63001892
# Iteration 309, loss = 0.63240005
# Iteration 310, loss = 0.63034256
# Iteration 311, loss = 0.62877579
# Iteration 312, loss = 0.62847625
# Iteration 313, loss = 0.62662068
# Iteration 314, loss = 0.62723375
# Iteration 315, loss = 0.62563953
# Iteration 316, loss = 0.62543824
# Iteration 317, loss = 0.62572545
# Iteration 318, loss = 0.62443312
# Iteration 319, loss = 0.62439707
# Iteration 320, loss = 0.62255610
# Iteration 321, loss = 0.62245055
# Iteration 322, loss = 0.62213558
# Iteration 323, loss = 0.62205896
# Iteration 324, loss = 0.62519465
# Iteration 325, loss = 0.61902676
# Iteration 326, loss = 0.62055970
# Iteration 327, loss = 0.61980910
# Iteration 328, loss = 0.61976489
# Iteration 329, loss = 0.61678706
# Iteration 330, loss = 0.61753336
# Iteration 331, loss = 0.61632356
# Iteration 332, loss = 0.61606903
# Iteration 333, loss = 0.61578425
# Iteration 334, loss = 0.61613371
# Iteration 335, loss = 0.61480284
# Iteration 336, loss = 0.61608418
# Iteration 337, loss = 0.61486296
# Iteration 338, loss = 0.61354584
# Iteration 339, loss = 0.61258304
# Iteration 340, loss = 0.61224925
# Iteration 341, loss = 0.61084954
# Iteration 342, loss = 0.61149265
# Iteration 343, loss = 0.61082665
# Iteration 344, loss = 0.61131944
# Iteration 345, loss = 0.60761514
# Iteration 346, loss = 0.60900891
# Iteration 347, loss = 0.60826800
# Iteration 348, loss = 0.60806243
# Iteration 349, loss = 0.60730711
# Iteration 350, loss = 0.60554429
# Iteration 351, loss = 0.60628096
# Iteration 352, loss = 0.60509546
# Iteration 353, loss = 0.60636640
# Iteration 354, loss = 0.60711978
# Iteration 355, loss = 0.60643391
# Iteration 356, loss = 0.60597203
# Iteration 357, loss = 0.60753517
# Iteration 358, loss = 0.60160064
# Iteration 359, loss = 0.60436250
# Iteration 360, loss = 0.60277484
# Iteration 361, loss = 0.60119042
# Iteration 362, loss = 0.60562310
# Iteration 363, loss = 0.59980191
# Iteration 364, loss = 0.60039942
# Iteration 365, loss = 0.59730783
# Iteration 366, loss = 0.59796765
# Iteration 367, loss = 0.59557611
# Iteration 368, loss = 0.59623188
# Iteration 369, loss = 0.59505477
# Iteration 370, loss = 0.59498778
# Iteration 371, loss = 0.59653509
# Iteration 372, loss = 0.59626323
# Iteration 373, loss = 0.59336819
# Iteration 374, loss = 0.59616720
# Iteration 375, loss = 0.59286982
# Iteration 376, loss = 0.59529486
# Iteration 377, loss = 0.59325126
# Iteration 378, loss = 0.59306357
# Iteration 379, loss = 0.59155136
# Iteration 380, loss = 0.59119262
# Iteration 381, loss = 0.59059604
# Iteration 382, loss = 0.59117693
# Iteration 383, loss = 0.58815424
# Iteration 384, loss = 0.59054719
# Iteration 385, loss = 0.58670533
# Iteration 386, loss = 0.59054825
# Iteration 387, loss = 0.59040828
# Iteration 388, loss = 0.58527892
# Iteration 389, loss = 0.59128647
# Iteration 390, loss = 0.58778993
# Iteration 391, loss = 0.58864046
# Iteration 392, loss = 0.58507461
# Iteration 393, loss = 0.58428091
# Iteration 394, loss = 0.58490943
# Iteration 395, loss = 0.58443393
# Iteration 396, loss = 0.58388866
# Iteration 397, loss = 0.58473606
# Iteration 398, loss = 0.58239277
# Iteration 399, loss = 0.58154040
# Iteration 400, loss = 0.58028529
# Iteration 401, loss = 0.58042969
# Iteration 402, loss = 0.57975436
# Iteration 403, loss = 0.57990203
# Iteration 404, loss = 0.58052875
# Iteration 405, loss = 0.58044569
# Iteration 406, loss = 0.58033729
# Iteration 407, loss = 0.58145142
# Iteration 408, loss = 0.57796934
# Iteration 409, loss = 0.57781283
# Iteration 410, loss = 0.57804742
# Iteration 411, loss = 0.57705631
# Iteration 412, loss = 0.58137732
# Iteration 413, loss = 0.57619389
# Iteration 414, loss = 0.57696723
# Iteration 415, loss = 0.57397825
# Iteration 416, loss = 0.57641322
# Iteration 417, loss = 0.57394666
# Iteration 418, loss = 0.57697472
# Iteration 419, loss = 0.57825779
# Iteration 420, loss = 0.57417553
# Iteration 421, loss = 0.57508774
# Iteration 422, loss = 0.57566670
# Iteration 423, loss = 0.57288752
# Iteration 424, loss = 0.57195682
# Iteration 425, loss = 0.57209205
# Iteration 426, loss = 0.57122750
# Iteration 427, loss = 0.57036029
# Iteration 428, loss = 0.56848369
# Iteration 429, loss = 0.56840553
# Iteration 430, loss = 0.56837900
# Iteration 431, loss = 0.56654580
# Iteration 432, loss = 0.56591950
# Iteration 433, loss = 0.56736604
# Iteration 434, loss = 0.56406573
# Iteration 435, loss = 0.56947862
# Iteration 436, loss = 0.56639434
# Iteration 437, loss = 0.56663783
# Iteration 438, loss = 0.56909002
# Iteration 439, loss = 0.56842802
# Iteration 440, loss = 0.56747810
# Iteration 441, loss = 0.56559870
# Iteration 442, loss = 0.56287140
# Iteration 443, loss = 0.56358999
# Iteration 444, loss = 0.56364214
# Iteration 445, loss = 0.56162647
# Iteration 446, loss = 0.56136451
# Iteration 447, loss = 0.55932414
# Iteration 448, loss = 0.56069982
# Iteration 449, loss = 0.55982869
# Iteration 450, loss = 0.55917633
# Iteration 451, loss = 0.55750694
# Iteration 452, loss = 0.56068793
# Iteration 453, loss = 0.55960912
# Iteration 454, loss = 0.55946609
# Iteration 455, loss = 0.55831144
# Iteration 456, loss = 0.55846104
# Iteration 457, loss = 0.55746748
# Iteration 458, loss = 0.55484935
# Iteration 459, loss = 0.55560569
# Iteration 460, loss = 0.55650799
# Iteration 461, loss = 0.55490909
# Iteration 462, loss = 0.55411683
# Iteration 463, loss = 0.55301504
# Iteration 464, loss = 0.55361617
# Iteration 465, loss = 0.55421908
# Iteration 466, loss = 0.55472422
# Iteration 467, loss = 0.55307737
# Iteration 468, loss = 0.55415604
# Iteration 469, loss = 0.55157890
# Iteration 470, loss = 0.55211867
# Iteration 471, loss = 0.55216482
# Iteration 472, loss = 0.55258888
# Iteration 473, loss = 0.54936623
# Iteration 474, loss = 0.54918357
# Iteration 475, loss = 0.55228016
# Iteration 476, loss = 0.54931583
# Iteration 477, loss = 0.55020676
# Iteration 478, loss = 0.54993271
# Iteration 479, loss = 0.55200005
# Iteration 480, loss = 0.54815647
# Iteration 481, loss = 0.55461875
# Iteration 482, loss = 0.55239813
# Iteration 483, loss = 0.55101292
# Iteration 484, loss = 0.54809743
# Iteration 485, loss = 0.54736535
# Iteration 486, loss = 0.54868452
# Iteration 487, loss = 0.54357726
# Iteration 488, loss = 0.54463826
# Iteration 489, loss = 0.54607187
# Iteration 490, loss = 0.54367531
# Iteration 491, loss = 0.54511457
# Iteration 492, loss = 0.54501469
# Iteration 493, loss = 0.54241671
# Iteration 494, loss = 0.54036176
# Iteration 495, loss = 0.54331422
# Iteration 496, loss = 0.54120121
# Iteration 497, loss = 0.54427240
# Iteration 498, loss = 0.54138074
# Iteration 499, loss = 0.54108086
# Iteration 500, loss = 0.54179351
# Iteration 501, loss = 0.54225188
# Iteration 502, loss = 0.54062049
# Iteration 503, loss = 0.54115462
# Iteration 504, loss = 0.54100049
# Iteration 505, loss = 0.53860272
# Iteration 506, loss = 0.54029903
# Iteration 507, loss = 0.53904544
# Iteration 508, loss = 0.53816423
# Iteration 509, loss = 0.53621060
# Iteration 510, loss = 0.53561461
# Iteration 511, loss = 0.53828870
# Iteration 512, loss = 0.53580799
# Iteration 513, loss = 0.53560631
# Iteration 514, loss = 0.53491747
# Iteration 515, loss = 0.53408978
# Iteration 516, loss = 0.53796506
# Iteration 517, loss = 0.53189061
# Iteration 518, loss = 0.53671932
# Iteration 519, loss = 0.53521957
# Iteration 520, loss = 0.53411090
# Iteration 521, loss = 0.53768706
# Iteration 522, loss = 0.53662411
# Iteration 523, loss = 0.53491573
# Iteration 524, loss = 0.53302618
# Iteration 525, loss = 0.53242036
# Iteration 526, loss = 0.53410290
# Iteration 527, loss = 0.53300831
# Iteration 528, loss = 0.53149026
# Iteration 529, loss = 0.53098554
# Iteration 530, loss = 0.52997834
# Iteration 531, loss = 0.53710428
# Iteration 532, loss = 0.52893637
# Iteration 533, loss = 0.53099299
# Iteration 534, loss = 0.53248643
# Iteration 535, loss = 0.52607524
# Iteration 536, loss = 0.53054122
# Iteration 537, loss = 0.52954663
# Iteration 538, loss = 0.52908457
# Iteration 539, loss = 0.52705704
# Iteration 540, loss = 0.52612638
# Iteration 541, loss = 0.52846881
# Iteration 542, loss = 0.52906336
# Iteration 543, loss = 0.53157193
# Iteration 544, loss = 0.52639823
# Iteration 545, loss = 0.52477059
# Iteration 546, loss = 0.52680241
# Iteration 547, loss = 0.52452579
# Iteration 548, loss = 0.52782944
# Iteration 549, loss = 0.52368193
# Iteration 550, loss = 0.52326645
# Iteration 551, loss = 0.52307707
# Iteration 552, loss = 0.52268062
# Iteration 553, loss = 0.52339836
# Iteration 554, loss = 0.52382921
# Iteration 555, loss = 0.52163875
# Iteration 556, loss = 0.52321839
# Iteration 557, loss = 0.52278891
# Iteration 558, loss = 0.51978479
# Iteration 559, loss = 0.52127641
# Iteration 560, loss = 0.51730988
# Iteration 561, loss = 0.52106694
# Iteration 562, loss = 0.51855137
# Iteration 563, loss = 0.52093925
# Iteration 564, loss = 0.52288744
# Iteration 565, loss = 0.51905205
# Iteration 566, loss = 0.51782066
# Iteration 567, loss = 0.51838507
# Iteration 568, loss = 0.51633650
# Iteration 569, loss = 0.51782051
# Iteration 570, loss = 0.51859510
# Iteration 571, loss = 0.51661090
# Iteration 572, loss = 0.51600756
# Iteration 573, loss = 0.51560409
# Iteration 574, loss = 0.51508173
# Iteration 575, loss = 0.51731543
# Iteration 576, loss = 0.51368894
# Iteration 577, loss = 0.51590827
# Iteration 578, loss = 0.51560980
# Iteration 579, loss = 0.51722055
# Iteration 580, loss = 0.51522859
# Iteration 581, loss = 0.51512219
# Iteration 582, loss = 0.51434197
# Iteration 583, loss = 0.51695553
# Iteration 584, loss = 0.51259778
# Iteration 585, loss = 0.51147986
# Iteration 586, loss = 0.51289001
# Iteration 587, loss = 0.50999253
# Iteration 588, loss = 0.51102444
# Iteration 589, loss = 0.51211356
# Iteration 590, loss = 0.51104080
# Iteration 591, loss = 0.51228660
# Iteration 592, loss = 0.51107635
# Iteration 593, loss = 0.51085293
# Iteration 594, loss = 0.51081412
# Iteration 595, loss = 0.50905394
# Iteration 596, loss = 0.50959655
# Iteration 597, loss = 0.51077806
# Iteration 598, loss = 0.51075310
# Iteration 599, loss = 0.51036150
# Iteration 600, loss = 0.50917139
# Iteration 601, loss = 0.50855405
# Iteration 602, loss = 0.51000357
# Iteration 603, loss = 0.50748608
# Iteration 604, loss = 0.50765837
# Iteration 605, loss = 0.50838775
# Iteration 606, loss = 0.50821701
# Iteration 607, loss = 0.50531240
# Iteration 608, loss = 0.50682873
# Iteration 609, loss = 0.50789796
# Iteration 610, loss = 0.50753449
# Iteration 611, loss = 0.50765078
# Iteration 612, loss = 0.50577243
# Iteration 613, loss = 0.50684278
# Iteration 614, loss = 0.50574840
# Iteration 615, loss = 0.50670907
# Iteration 616, loss = 0.50465207
# Iteration 617, loss = 0.50253033
# Iteration 618, loss = 0.50638777
# Iteration 619, loss = 0.50377787
# Iteration 620, loss = 0.50410493
# Iteration 621, loss = 0.50177733
# Iteration 622, loss = 0.50063678
# Iteration 623, loss = 0.50420477
# Iteration 624, loss = 0.50112544
# Iteration 625, loss = 0.50304352
# Iteration 626, loss = 0.50089183
# Iteration 627, loss = 0.50244611
# Iteration 628, loss = 0.49951427
# Iteration 629, loss = 0.50247295
# Iteration 630, loss = 0.50292218
# Iteration 631, loss = 0.50304465
# Iteration 632, loss = 0.50245453
# Iteration 633, loss = 0.49822413
# Iteration 634, loss = 0.49811685
# Iteration 635, loss = 0.49839325
# Iteration 636, loss = 0.49871026
# Iteration 637, loss = 0.50076216
# Iteration 638, loss = 0.49692032
# Iteration 639, loss = 0.50086535
# Iteration 640, loss = 0.49849512
# Iteration 641, loss = 0.49832694
# Iteration 642, loss = 0.49706168
# Iteration 643, loss = 0.49473339
# Iteration 644, loss = 0.49681770
# Iteration 645, loss = 0.49473051
# Iteration 646, loss = 0.49915143
# Iteration 647, loss = 0.49402003
# Iteration 648, loss = 0.49699021
# Iteration 649, loss = 0.50205102
# Iteration 650, loss = 0.49794626
# Iteration 651, loss = 0.49704527
# Iteration 652, loss = 0.49341349
# Iteration 653, loss = 0.49663310
# Iteration 654, loss = 0.49426436
# Iteration 655, loss = 0.49709442
# Iteration 656, loss = 0.49220519
# Iteration 657, loss = 0.49406264
# Iteration 658, loss = 0.49251871
# Iteration 659, loss = 0.49590870
# Iteration 660, loss = 0.49196045
# Iteration 661, loss = 0.49440158
# Iteration 662, loss = 0.49377358
# Iteration 663, loss = 0.49278349
# Iteration 664, loss = 0.49658347
# Iteration 665, loss = 0.48961825
# Iteration 666, loss = 0.49423473
# Iteration 667, loss = 0.49290586
# Iteration 668, loss = 0.49503485
# Iteration 669, loss = 0.49226772
# Iteration 670, loss = 0.49047318
# Iteration 671, loss = 0.49036056
# Iteration 672, loss = 0.49034837
# Iteration 673, loss = 0.49030698
# Iteration 674, loss = 0.49114774
# Iteration 675, loss = 0.48715591
# Iteration 676, loss = 0.49183613
# Iteration 677, loss = 0.48856858
# Iteration 678, loss = 0.48857724
# Iteration 679, loss = 0.48867672
# Iteration 680, loss = 0.48661674
# Iteration 681, loss = 0.48804924
# Iteration 682, loss = 0.48923579
# Iteration 683, loss = 0.48905084
# Iteration 684, loss = 0.48892513
# Iteration 685, loss = 0.48738483
# Iteration 686, loss = 0.48475402
# Iteration 687, loss = 0.48587157
# Iteration 688, loss = 0.48894053
# Iteration 689, loss = 0.48691548
# Iteration 690, loss = 0.48475465
# Iteration 691, loss = 0.48729102
# Iteration 692, loss = 0.48894019
# Iteration 693, loss = 0.48431947
# Iteration 694, loss = 0.48927350
# Iteration 695, loss = 0.48636371
# Iteration 696, loss = 0.48617086
# Iteration 697, loss = 0.48269068
# Iteration 698, loss = 0.48758454
# Iteration 699, loss = 0.48469690
# Iteration 700, loss = 0.48547858
# Iteration 701, loss = 0.48338102
# Iteration 702, loss = 0.48571003
# Iteration 703, loss = 0.48656221
# Iteration 704, loss = 0.48252513
# Iteration 705, loss = 0.48218066
# Iteration 706, loss = 0.48207742
# Iteration 707, loss = 0.48323672
# Iteration 708, loss = 0.48120618
# Iteration 709, loss = 0.48435231
# Iteration 710, loss = 0.47923240
# Iteration 711, loss = 0.48037557
# Iteration 712, loss = 0.48037886
# Iteration 713, loss = 0.47830211
# Iteration 714, loss = 0.48031611
# Iteration 715, loss = 0.47788240
# Iteration 716, loss = 0.47845954
# Iteration 717, loss = 0.47820366
# Iteration 718, loss = 0.47831157
# Iteration 719, loss = 0.48451276
# Iteration 720, loss = 0.47782755
# Iteration 721, loss = 0.48016060
# Iteration 722, loss = 0.47953626
# Iteration 723, loss = 0.47870882
# Iteration 724, loss = 0.47635534
# Iteration 725, loss = 0.47739711
# Iteration 726, loss = 0.47559543
# Iteration 727, loss = 0.47606177
# Iteration 728, loss = 0.47424621
# Iteration 729, loss = 0.47484412
# Iteration 730, loss = 0.47658384
# Iteration 731, loss = 0.47338438
# Iteration 732, loss = 0.48005859
# Iteration 733, loss = 0.47312586
# Iteration 734, loss = 0.47539376
# Iteration 735, loss = 0.47438720
# Iteration 736, loss = 0.47491349
# Iteration 737, loss = 0.47338216
# Iteration 738, loss = 0.47465766
# Iteration 739, loss = 0.47251900
# Iteration 740, loss = 0.47268347
# Iteration 741, loss = 0.47146871
# Iteration 742, loss = 0.47183212
# Iteration 743, loss = 0.47128261
# Iteration 744, loss = 0.47342467
# Iteration 745, loss = 0.47146628
# Iteration 746, loss = 0.47480730
# Iteration 747, loss = 0.47204418
# Iteration 748, loss = 0.47256749
# Iteration 749, loss = 0.46947397
# Iteration 750, loss = 0.47432431
# Iteration 751, loss = 0.47097955
# Iteration 752, loss = 0.47227686
# Iteration 753, loss = 0.47337924
# Iteration 754, loss = 0.46864744
# Iteration 755, loss = 0.47297092
# Iteration 756, loss = 0.46841154
# Iteration 757, loss = 0.47165540
# Iteration 758, loss = 0.46998156
# Iteration 759, loss = 0.46968102
# Iteration 760, loss = 0.47227692
# Iteration 761, loss = 0.47056696
# Iteration 762, loss = 0.47009719
# Iteration 763, loss = 0.46729120
# Iteration 764, loss = 0.46784152
# Iteration 765, loss = 0.46812100
# Iteration 766, loss = 0.46734521
# Iteration 767, loss = 0.46572148
# Iteration 768, loss = 0.47061607
# Iteration 769, loss = 0.46683749
# Iteration 770, loss = 0.46716998
# Iteration 771, loss = 0.46780652
# Iteration 772, loss = 0.46704821
# Iteration 773, loss = 0.46784452
# Iteration 774, loss = 0.46710964
# Iteration 775, loss = 0.46607912
# Iteration 776, loss = 0.46493064
# Iteration 777, loss = 0.46556354
# Iteration 778, loss = 0.46592248
# Iteration 779, loss = 0.46582875
# Iteration 780, loss = 0.46666581
# Iteration 781, loss = 0.46726360
# Iteration 782, loss = 0.46970479
# Iteration 783, loss = 0.46409420
# Iteration 784, loss = 0.46466390
# Iteration 785, loss = 0.46301572
# Iteration 786, loss = 0.46170685
# Iteration 787, loss = 0.46176793
# Iteration 788, loss = 0.46194605
# Iteration 789, loss = 0.46202210
# Iteration 790, loss = 0.46208214
# Iteration 791, loss = 0.46257678
# Iteration 792, loss = 0.46309949
# Iteration 793, loss = 0.46172499
# Iteration 794, loss = 0.46355838
# Iteration 795, loss = 0.46189000
# Iteration 796, loss = 0.46007942
# Iteration 797, loss = 0.46137227
# Iteration 798, loss = 0.45971577
# Iteration 799, loss = 0.46137453
# Iteration 800, loss = 0.46159863
# Iteration 801, loss = 0.46272685
# Iteration 802, loss = 0.45935514
# Iteration 803, loss = 0.46136934
# Iteration 804, loss = 0.46130000
# Iteration 805, loss = 0.46088932
# Iteration 806, loss = 0.45981562
# Iteration 807, loss = 0.46359885
# Iteration 808, loss = 0.45916413
# Iteration 809, loss = 0.46264097
# Iteration 810, loss = 0.46011268
# Iteration 811, loss = 0.45837863
# Iteration 812, loss = 0.45937504
# Iteration 813, loss = 0.46180681
# Iteration 814, loss = 0.46268990
# Iteration 815, loss = 0.46224060
# Iteration 816, loss = 0.45982003
# Iteration 817, loss = 0.45721530
# Iteration 818, loss = 0.46390867
# Iteration 819, loss = 0.45946163
# Iteration 820, loss = 0.45915737
# Iteration 821, loss = 0.45764019
# Iteration 822, loss = 0.45908193
# Iteration 823, loss = 0.46182511
# Iteration 824, loss = 0.45486676
# Iteration 825, loss = 0.45830274
# Iteration 826, loss = 0.45833933
# Iteration 827, loss = 0.46015422
# Iteration 828, loss = 0.45591451
# Iteration 829, loss = 0.45478241
# Iteration 830, loss = 0.45553711
# Iteration 831, loss = 0.45423685
# Iteration 832, loss = 0.45468825
# Iteration 833, loss = 0.45406593
# Iteration 834, loss = 0.45732863
# Iteration 835, loss = 0.45717916
# Iteration 836, loss = 0.45575381
# Iteration 837, loss = 0.45721726
# Iteration 838, loss = 0.45301433
# Iteration 839, loss = 0.45523084
# Iteration 840, loss = 0.45466911
# Iteration 841, loss = 0.45482649
# Iteration 842, loss = 0.45337123
# Iteration 843, loss = 0.45553180
# Iteration 844, loss = 0.45612189
# Iteration 845, loss = 0.45227297
# Iteration 846, loss = 0.45124455
# Iteration 847, loss = 0.45258014
# Iteration 848, loss = 0.45413516
# Iteration 849, loss = 0.45159947
# Iteration 850, loss = 0.45159372
# Iteration 851, loss = 0.44982626
# Iteration 852, loss = 0.45205079
# Iteration 853, loss = 0.45550421
# Iteration 854, loss = 0.45064835
# Iteration 855, loss = 0.45324065
# Iteration 856, loss = 0.44974402
# Iteration 857, loss = 0.45054430
# Iteration 858, loss = 0.45222759
# Iteration 859, loss = 0.45277597
# Iteration 860, loss = 0.44943178
# Iteration 861, loss = 0.45121814
# Iteration 862, loss = 0.45015586
# Iteration 863, loss = 0.45165593
# Iteration 864, loss = 0.44847265
# Iteration 865, loss = 0.44811612
# Iteration 866, loss = 0.44957985
# Iteration 867, loss = 0.44711073
# Iteration 868, loss = 0.44761360
# Iteration 869, loss = 0.44795058
# Iteration 870, loss = 0.44582158
# Iteration 871, loss = 0.44677298
# Iteration 872, loss = 0.45001416
# Iteration 873, loss = 0.45131302
# Iteration 874, loss = 0.45624243
# Iteration 875, loss = 0.44710429
# Iteration 876, loss = 0.45344922
# Iteration 877, loss = 0.44947314
# Iteration 878, loss = 0.44869057
# Iteration 879, loss = 0.44881620
# Iteration 880, loss = 0.44659632
# Iteration 881, loss = 0.44477656
# Iteration 882, loss = 0.44449636
# Iteration 883, loss = 0.44610287
# Iteration 884, loss = 0.44374471
# Iteration 885, loss = 0.44523896
# Iteration 886, loss = 0.44340781
# Iteration 887, loss = 0.44467455
# Iteration 888, loss = 0.44600904
# Iteration 889, loss = 0.44800642
# Iteration 890, loss = 0.44448527
# Iteration 891, loss = 0.44550001
# Iteration 892, loss = 0.44585501
# Iteration 893, loss = 0.44412587
# Iteration 894, loss = 0.44421536
# Iteration 895, loss = 0.44421273
# Iteration 896, loss = 0.44443764
# Iteration 897, loss = 0.44279842
# Iteration 898, loss = 0.44655246
# Iteration 899, loss = 0.44318545
# Iteration 900, loss = 0.44829034
# Iteration 901, loss = 0.44389283
# Iteration 902, loss = 0.44276258
# Iteration 903, loss = 0.44304037
# Iteration 904, loss = 0.44454597
# Iteration 905, loss = 0.44711648
# Iteration 906, loss = 0.44066457
# Iteration 907, loss = 0.44391174
# Iteration 908, loss = 0.43886468
# Iteration 909, loss = 0.44282454
# Iteration 910, loss = 0.44053086
# Iteration 911, loss = 0.44154301
# Iteration 912, loss = 0.44242828
# Iteration 913, loss = 0.44016095
# Iteration 914, loss = 0.44084018
# Iteration 915, loss = 0.43910529
# Iteration 916, loss = 0.43877320
# Iteration 917, loss = 0.43949040
# Iteration 918, loss = 0.44263360
# Iteration 919, loss = 0.44068744
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(60,), max_iter=3000, verbose=True)

# %%
mlp.predict(X_test_mlp)
# Out:
# array(['7', '5', '4', '2', '4', '7', '8', '8', '1', '6', '4', '5', '1',
#        '5', '1', '3', '5', '2', '6', '9', '5', '9', '7', '9', '9', '8',
#        '0', '8', '4', '8', '4', '2', '0', '7', '6', '4', '8', '1', '3',
#        '2', '8', '9', '5', '2', '7', '4', '0', '2', '6', '8', '6', '4',
#        '5', '9', '1', '3', '6', '9', '8', '1', '9', '7', '0', '9', '7',
#        '0', '2', '6', '4', '3', '8', '3', '2', '4', '8', '0', '5', '8',
#        '7', '6', '1', '4', '4', '3', '4', '3', '3', '1', '9', '6', '0',
#        '7', '2', '1', '7', '9', '6', '9', '0', '3'], dtype='<U1')

# %%
accuracy_score(y_test,mlp.predict(X_test_mlp))
# Out:
# 0.82
